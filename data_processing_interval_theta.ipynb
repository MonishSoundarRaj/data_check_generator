# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/data_check_generator/blob/main/data_processing_interval_theta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_theta_cgs.csv")
df.head(10)
# Out:
#    Unnamed: 0  job          user       project  state  gpu_num      cpu_num  \
# 0           0    0  9.536262e+12  3.398925e+13      0        0   128.000000
# 1           1    1  7.977642e+13  8.131041e+13      0        0  7966.741827
# 2           2    2  8.298257e+12  9.730273e+12      0        0   128.000000
# 3           3    3  0.000000e+00  0.000000e+00      0        0  8528.853289
# 4           4    4  3.457643e+13  3.428432e+13      0        0   504.950253
# 5           5    5  9.799802e+12  1.160952e+13      0        0   128.000000
# 6           6    6  9.823513e+12  9.320160e+12      0        0   128.000000
# 7           7    7  0.000000e+00  1.085747e+13      0        0  8236.619597
# 8           8    8  0.000000e+00  0.000000e+00      0        0   499.225623
# 9           9    9  0.000000e+00  5.924164e+13      0        0   128.000000
#
#       node_num     run_time     wall_time new_status     interval
# 0     8.172746    61.651559   3574.058407     Failed   804.253962
# ...

# %%
df['interval'].isna().sum()
# Out:
# 1

# %%
# prompt: Print the row in df that has the Nan in the interval colums

df.loc[df['interval'].isna()]
# Out:
#       Unnamed: 0   job          user       project  state  gpu_num  \
# 7351        7351  7351  3.426188e+13  3.381246e+13      0        0
#
#          cpu_num  node_num    run_time   wall_time new_status  interval
# 7351  466.170933  7.472707  751.670618  3644.30659       Pass       NaN

# %%
# prompt: how to ascend the rows based on the values of the intervals

df['interval'] = df['interval'].fillna(0)
df.sort_values('interval', inplace=True)
df.head(10)
# Out:
#       Unnamed: 0   job          user       project  state  gpu_num  \
# 7351        7351  7351  3.426188e+13  3.381246e+13      0        0
# 4654        4654  4654  5.904793e+13  0.000000e+00      0        0
# 5891        5891  5891  9.250945e+13  7.181096e+13      0        0
# 4566        4566  4566  0.000000e+00  7.110159e+13      0        0
# 6436        6436  6436  0.000000e+00  0.000000e+00      0        0
# 6936        6936  6936  8.279438e+13  7.975331e+13      0        0
# 3157        3157  3157  7.759730e+10  0.000000e+00      0        0
# 9573        9573  9573  8.271674e+13  8.066162e+13      0        0
# 979          979   979  0.000000e+00  0.000000e+00      0        0
# 4207        4207  4207  0.000000e+00  0.000000e+00      0        0
#
#            cpu_num    node_num      run_time     wall_time new_status  \
# 7351    466.170933    7.472707    751.670618   3644.306590       Pass
# 4654  47562.098784  136.636613   1056.303193  10846.787793       Pass
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0   job          user       project  state  gpu_num  \
# 1496        1496  1496  7.005899e+13  5.935124e+13      0        0
# 8587        8587  8587  6.035430e+13  5.993203e+13      0        0
# 5693        5693  5693  4.248141e+13  9.718933e+13      0        0
# 1378        1378  1378  7.204937e+13  7.167015e+13      0        0
# 1501        1501  1501  3.438024e+13  4.217810e+13      0        0
#
#           cpu_num    node_num      run_time     wall_time new_status  \
# 1496  7922.168109  114.064692    227.900896  92516.744834     Killed
# 8587  7957.583475  128.495038  11004.275096  11010.609081     Killed
# 5693   128.000000    2.000000    113.015371   3566.990384       Pass
# 1378   208.703101    2.000000   1461.279907   3645.585197       Pass
# 1501   128.000000    2.000000    128.945039   3605.408947       Pass
#
#           interval
# 1496  28877.162527
# 8587  31400.020863
# 5693  36563.144845
# 1378  40521.491478
# 1501  44500.489009

# %%
df.loc[df['interval'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, job, user, project, state, gpu_num, cpu_num, node_num, run_time, wall_time, new_status, interval]
# Index: []

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#        job          user       project  state  gpu_num       cpu_num  \
# 7351  7351  3.426188e+13  3.381246e+13      0        0    466.170933
# 4654  4654  5.904793e+13  0.000000e+00      0        0  47562.098784
# 5891  5891  9.250945e+13  7.181096e+13      0        0    128.000000
# 4566  4566  0.000000e+00  7.110159e+13      0        0   7829.477215
# 6436  6436  0.000000e+00  0.000000e+00      0        0   8635.547259
#
#         node_num      run_time     wall_time new_status      interval
# 7351    7.472707    751.670618   3644.306590       Pass  0.000000e+00
# 4654  136.636613   1056.303193  10846.787793       Pass  4.480142e-18
# 5891    2.000000    134.088537   3533.104312       Pass  3.606534e-17
# 4566  128.193337     64.132717  10846.900281     Killed  4.109779e-16
# 6436  124.600919  10852.835141  21552.752457     Killed  1.006297e-15

# %%
df.to_csv("data_theta_updated_cgs.csv")
