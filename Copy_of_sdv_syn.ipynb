# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/data_check_generator/blob/main/Copy_of_sdv_syn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sdv

# %%
import pandas as pd
import numpy as np

# %%
df_main = pd.read_csv("data_supercloud.csv")
df_main.drop("Unnamed: 0", axis=1, inplace=True)
df_main.head()
# Out:
#    Unnamed: 0.1             job            user  project  state  gpu_num  \
# 0        229155  89774853202668  14611672037819        0      5        1
# 1        229159  38956485658324  14611672037819        0      5        1
# 2        229161   1055093933909  14611672037819        0      5        1
# 3        229164  17584591333033   2292481130222        0      6        1
# 4        229172  76793457742827  32195694464536        0      5        2
#
#    cpu_num  node_num  submit_time  wait_time  run_time  wall_time  node_hour  \
# 0       20         1   1622520080          1       467          0   0.129722
# 1       20         1   1622520698          1      1637          0   0.454722
# 2       20         1   1622521935          2     33148          0   9.207778
# 3       20         1   1622522749          2     86426          0  24.007222
# 4       40         1   1622525373          0      1170          0   0.325000
#
#   new_status
# 0     Killed
# 1     Killed
# 2     Killed
# ...

# %%
df_main.drop("Unnamed: 0.1", axis=1, inplace=True)

# %%
df = df_main.sort_values(by='submit_time', ascending=True)
df.head()
# Out:
#               job            user  project  state  gpu_num  cpu_num  node_num  \
# 0  89774853202668  14611672037819        0      5        1       20         1
# 1  38956485658324  14611672037819        0      5        1       20         1
# 2   1055093933909  14611672037819        0      5        1       20         1
# 3  17584591333033   2292481130222        0      6        1       20         1
# 4  76793457742827  32195694464536        0      5        2       40         1
#
#    submit_time  wait_time  run_time  wall_time  node_hour new_status
# 0   1622520080          1       467          0   0.129722     Killed
# 1   1622520698          1      1637          0   0.454722     Killed
# 2   1622521935          2     33148          0   9.207778     Killed
# 3   1622522749          2     86426          0  24.007222       Pass
# 4   1622525373          0      1170          0   0.325000     Killed

# %%
from sdv.metadata import SingleTableMetadata
df.drop(columns=["node_hour", "wait_time"], inplace=True)
df['interval'] = df['submit_time'] - df['submit_time'].shift(1)
df.head()
# Out:
#               job            user  project  state  gpu_num  cpu_num  node_num  \
# 0  89774853202668  14611672037819        0      5        1       20         1
# 1  38956485658324  14611672037819        0      5        1       20         1
# 2   1055093933909  14611672037819        0      5        1       20         1
# 3  17584591333033   2292481130222        0      6        1       20         1
# 4  76793457742827  32195694464536        0      5        2       40         1
#
#    submit_time  run_time  wall_time new_status  interval
# 0   1622520080       467          0     Killed       NaN
# 1   1622520698      1637          0     Killed     618.0
# 2   1622521935     33148          0     Killed    1237.0
# 3   1622522749     86426          0       Pass     814.0
# 4   1622525373      1170          0     Killed    2624.0

# %%
df.drop(columns=["submit_time"], inplace=True)

# %%
count_negatives = (df['interval'] < 0).sum()
print(count_negatives)
# Out:
# 0

# %%
metadata = SingleTableMetadata()

# %%
metadata.detect_from_dataframe(data=df)

# %%
print(metadata)
# Out:
# {
#     "primary_key": "job",
#     "columns": {
#         "job": {
#             "sdtype": "id"
#         },
#         "user": {
#             "sdtype": "numerical"
#         },
#         "project": {
#             "sdtype": "categorical"
#         },
#         "state": {
#             "sdtype": "categorical"
#         },
#         "gpu_num": {
#             "sdtype": "numerical"
#         },
#         "cpu_num": {
#             "sdtype": "numerical"
#         },
#         "node_num": {
#             "sdtype": "numerical"
#         },
#         "run_time": {
#             "sdtype": "numerical"
#         },
#         "wall_time": {
#             "sdtype": "categorical"
#         },
#         "new_status": {
#             "sdtype": "categorical"
#         },
#         "interval": {
#             "sdtype": "numerical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }

# %%
df.head()
# Out:
#               job            user  project  state  gpu_num  cpu_num  node_num  \
# 0  89774853202668  14611672037819        0      5        1       20         1
# 1  38956485658324  14611672037819        0      5        1       20         1
# 2   1055093933909  14611672037819        0      5        1       20         1
# 3  17584591333033   2292481130222        0      6        1       20         1
# 4  76793457742827  32195694464536        0      5        2       40         1
#
#    run_time  wall_time new_status  interval
# 0       467          0     Killed       NaN
# 1      1637          0     Killed     618.0
# 2     33148          0     Killed    1237.0
# 3     86426          0       Pass     814.0
# 4      1170          0     Killed    2624.0

# %%
# from sdv.single_table import CTGANSynthesizer

# synthesizer = CTGANSynthesizer(
#     metadata,
#     enforce_rounding=False,
#     epochs=30,
#     verbose=True
# )
# synthesizer.fit(theta_df.head(14000))

# synthetic_data = synthesizer.sample(num_rows=10000)

# %%
# print(synthetic_data)

# %%
# from google.colab import files
# synthetic_data.to_csv("syn_ctgan_theta.csv")
# files.download("syn_ctgan_theta.csv")

# %%
# from sdv.single_table import TVAESynthesizer

# synthesizer_TVAE = TVAESynthesizer(
#     metadata,
#     enforce_min_max_values=True,
#     enforce_rounding=False,
#     epochs=100,
# )

# synthesizer_TVAE.fit(theta_df.head(13000))
# synthetic_data_tvae = synthesizer_TVAE.sample(num_rows=1000)

# %%
# print(synthetic_data_tvae)

# %%
# from google.colab import files
# synthetic_data_tvae.to_csv("syn_tvae_theta_epochs100.csv")
# files.download("syn_tvae_theta_epochs100.csv")

# %%
# theta_df.columns

# %%
# from sdv.single_table import GaussianCopulaSynthesizer

# synthesizer_gcs = GaussianCopulaSynthesizer(
#     metadata, # required
#     enforce_min_max_values=True,
#     enforce_rounding=False,
#     numerical_distributions={
#         'user': 'gaussian_kde',
#         'project': 'gaussian_kde',
#     },
#     default_distribution='beta'
# )

# synthesizer_gcs.fit(theta_df.head(13000))

# synthetic_data_gcs = synthesizer_gcs.sample(num_rows=10000)

# %%
# #this there is a ? to how to do the new_status as it is categ-cal and not right or frequency based as project
# synthetic_data_gcs.head()

# %%
# synthetic_data_gcs.to_csv("data_theta_gcs.csv")
# from google.colab import files
# files.download("data_theta_gcs.csv")

# %%
from sdv.single_table import CopulaGANSynthesizer

synthesizer_cgs = CopulaGANSynthesizer(
    metadata,
    enforce_min_max_values=True,
    enforce_rounding=False,
    numerical_distributions={
        'user': 'gaussian_kde',
        'project': 'gaussian_kde',
    },
    epochs=100,
    verbose=True
)

synthesizer_cgs.fit(df.head(13000))

synthetic_data_cgs = synthesizer_cgs.sample(num_rows=10000)
# Out:
# Gen. (-0.17) | Discrim. (0.06): 100%|██████████| 100/100 [03:54<00:00,  2.35s/it]

# %%
synthetic_data_cgs.head(20)
# Out:
#     job            user  project  state  gpu_num  cpu_num  node_num  run_time  \
# 0     0  87718288239424        0      3        1       20         6     60327
# 1     1  51554884524541        0      3        1       20         2     43431
# 2     2  54207134732156        0      3        1       11         2      2289
# 3     3  50361206020501        0      4        1        4         2      6988
# 4     4  51716593853572        0      5        2       20         2    134627
# 5     5  31252024785425        0      3        0        2         2       464
# 6     6  15948498955027        0      4        0        2         2     38484
# 7     7  51478427891672        0      3        0        2         2     89672
# 8     8  66810309948538        0      4        1       19         2      3696
# 9     9  42613681129167        0      5        1       44         2       405
# 10   10   5814347166643        0      3        0       11         2     18039
# ...

# %%
synthetic_data_cgs.to_csv("data_sc_cgs.csv")
from google.colab import files
files.download("data_sc_cgs.csv")

# %%
synthesizer_cgs.save(
    filepath='cgs_100_sc.pkl'
)
