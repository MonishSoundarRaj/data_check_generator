# %% [markdown]
# <a href="https://colab.research.google.com/github/MonishSoundarRaj/data_check_generator/blob/main/theta_hist_cgs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
theta_df = pd.read_csv("data_theta_cgs.csv")
theta_df.head(10)
# Out:
#    Unnamed: 0  job          user       project  state  gpu_num       cpu_num  \
# 0           0    0  1.137594e+13  7.989154e+13      0        0    128.000000
# 1           1    1  7.061407e+13  0.000000e+00      0        0  41507.927342
# 2           2    2  0.000000e+00  0.000000e+00      0        0  54120.634161
# 3           3    3  8.130264e+13  8.474712e+13      0        0   7615.052287
# 4           4    4  0.000000e+00  3.459157e+13      0        0  55912.404572
# 5           5    5  1.056523e+13  7.696237e+12      0        0    128.000000
# 6           6    6  8.112865e+10  0.000000e+00      0        0  17168.294571
# 7           7    7  0.000000e+00  1.279322e+11      0        0    486.793766
# 8           8    8  1.021737e+13  7.946885e+13      0        0    128.000000
# 9           9    9  5.945056e+13  6.052961e+13      0        0   7924.892368
#
#       node_num  submit_time  wait_time      run_time     wall_time  \
# ...

# %%
theta_df['wait_time'].hist(bins=10, edgecolor='black')
plt.title('Histogram of Wait Time')
plt.xlabel('Wait Time')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['submit_time'].hist(bins=50, edgecolor='black')
plt.title('Histogram of Submit Time')
plt.xlabel('Submit Time')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['run_time'].hist(bins=50, edgecolor='black')
plt.title('Histogram of run_time')
plt.xlabel('run_time')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['wall_time'].hist(bins=50, edgecolor='black')
plt.title('Histogram of wall_time')
plt.xlabel('wall_time')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['node_hour'].hist(bins=50, edgecolor='black')
plt.title('Histogram of node_hour')
plt.xlabel('node_hour')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['cpu_num'].hist(bins=50, edgecolor='black')
plt.title('Histogram of cpu_num')
plt.xlabel('cpu_num')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['node_num'].hist(bins=50, edgecolor='black')
plt.title('Histogram of node_num')
plt.xlabel('node_num')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['user'].hist(bins=50, edgecolor='black')
plt.title('Histogram of node_num')
plt.xlabel('node_num')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()

# %%
theta_df['new_status'].hist(bins=50, edgecolor='black')
plt.title('Histogram of node_num')
plt.xlabel('node_num')
plt.ylabel('Number of Jobs')
plt.grid(False)
plt.show()
